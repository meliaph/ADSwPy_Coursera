# %% [markdown]
# **Applied Data Science with Python Specialization (Coursera)**
# #### **Course 1: Introduction to Data Science in Python (C1)**
#
# ## **(Week 3) - (4) Scales**

# %%
#Importing the Library
import pandas as pd

# %%
#Creating the Dataset
df=pd.DataFrame(['A+','A','A-','B+','B','B-','C+','C','C-','D+','D'],
                index=['excellent','excellent','excellent','good','good','good',
                       'ok','ok','ok','poor','poor'],
                columns=["Grades"])

df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D

# %%
#Changing the Data Type
df["Grades"].astype("category")
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# ok            C
# ok           C-
# poor         D+
# poor          D
# Name: Grades, dtype: category
# Categories (11, object): ['A', 'A+', 'A-', 'B', ..., 'C+', 'C-', 'D', 'D+']

# %%
my_categories=pd.CategoricalDtype(categories=['D','D+','C-','C','C+','B-','B','B+','A-','A','A+'],
                                  ordered=True)

#Passing "my_categories" to the astype() function
grades=df["Grades"].astype(my_categories)
grades
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# ok            C
# ok           C-
# poor         D+
# poor          D
# Name: Grades, dtype: category
# Categories (11, object): ['D' < 'D+' < 'C-' < 'C' ... 'B+' < 'A-' < 'A' < 'A+']

# %%
#Lexicographical comparison of the list of grades to certain grade
df[df["Grades"]>"C"]
# Out:
#      Grades
# ok       C+
# ok       C-
# poor     D+
# poor      D

# %%
grades[grades>"C"]
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# Name: Grades, dtype: category
# Categories (11, object): ['D' < 'D+' < 'C-' < 'C' ... 'B+' < 'A-' < 'A' < 'A+']

# %% [markdown]
# #####

# %%
import numpy as np

# %%
df=pd.read_csv("datasets/census.csv")
df=df[df['SUMLEV']==50]
df=df.set_index('STNAME').groupby(level=0)['CENSUS2010POP'].agg(np.average)
df.sample(n=7)

# %%
pd.cut(df,10)
