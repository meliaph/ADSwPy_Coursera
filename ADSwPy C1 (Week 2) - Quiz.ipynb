# %%
#1 For the following code, which of the following statements will not return True?
import pandas as pd

sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj1 = pd.Series(sdata)
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj2 = pd.Series(sdata, index=states)
obj3 = pd.isnull(obj2)

# %%
obj3['California']
# Out:
# True

# %%
import math
math.isnan(obj2['California'])
# Out:
# True

# %%
obj2['California']==None
# Out:
# False

# %%
x=obj2['California']
obj2['California']!=x
# Out:
# True

# %%
#2 In the above python code, the keys of the dictionary d represent student ranks and the value for each key is a student name. 
#Which of the following can be used to extract rows with student ranks that are lower than or equal to 3?
d = {'1': 'Alice','2': 'Bob','3': 'Rita','4': 'Molly','5': 'Ryan'}
S = pd.Series(d)

# %%
S.iloc[0:3]
# Out:
# 1    Alice
# 2      Bob
# 3     Rita
# dtype: object

# %%
#3 Suppose we have a DataFrame named df. We want to change the original
#DataFrame df in a way that all the column names are cast to upper case. 
#Which of the following expressions is incorrect to perform the same?

url='https://drive.google.com/uc?export=download&id=153aMLlWJ6c_eb_nEXetlL_Yl4oog08Mj'
df=pd.read_csv(url)
df.head()
# Out:
#    age          workclass  fnlwgt  ... hours-per-week         country  salary
# 0   39          State-gov   77516  ...             40   United-States   <=50K
# 1   50   Self-emp-not-inc   83311  ...             13   United-States   <=50K
# 2   38            Private  215646  ...             40   United-States   <=50K
# 3   53            Private  234721  ...             40   United-States   <=50K
# 4   28            Private  338409  ...             40            Cuba   <=50K
#
# [5 rows x 15 columns]

# %%
df.rename(mapper = lambda x: x.upper(), axis = 1, inplace = True)
df.head()
# Out:
#    AGE          WORKCLASS  FNLWGT  ... HOURS-PER-WEEK         COUNTRY  SALARY
# 0   39          State-gov   77516  ...             40   United-States   <=50K
# 1   50   Self-emp-not-inc   83311  ...             13   United-States   <=50K
# 2   38            Private  215646  ...             40   United-States   <=50K
# 3   53            Private  234721  ...             40   United-States   <=50K
# 4   28            Private  338409  ...             40            Cuba   <=50K
#
# [5 rows x 15 columns]

# %%
df=df.rename(mapper=lambda x: x.upper(), axis=1)
df.head()
# Out:
#    AGE          WORKCLASS  FNLWGT  ... HOURS-PER-WEEK         COUNTRY  SALARY
# 0   39          State-gov   77516  ...             40   United-States   <=50K
# 1   50   Self-emp-not-inc   83311  ...             13   United-States   <=50K
# 2   38            Private  215646  ...             40   United-States   <=50K
# 3   53            Private  234721  ...             40   United-States   <=50K
# 4   28            Private  338409  ...             40            Cuba   <=50K
#
# [5 rows x 15 columns]

# %%
df.rename(mapper = lambda x: x.upper(), axis = 1)
df.head()
# Out:
#    age          workclass  fnlwgt  ... hours-per-week         country  salary
# 0   39          State-gov   77516  ...             40   United-States   <=50K
# 1   50   Self-emp-not-inc   83311  ...             13   United-States   <=50K
# 2   38            Private  215646  ...             40   United-States   <=50K
# 3   53            Private  234721  ...             40   United-States   <=50K
# 4   28            Private  338409  ...             40            Cuba   <=50K
#
# [5 rows x 15 columns]

# %%
df = df.rename(mapper = lambda x: x.upper(), axis = 'columns')
df.head()
# Out:
#    AGE          WORKCLASS  FNLWGT  ... HOURS-PER-WEEK         COUNTRY  SALARY
# 0   39          State-gov   77516  ...             40   United-States   <=50K
# 1   50   Self-emp-not-inc   83311  ...             13   United-States   <=50K
# 2   38            Private  215646  ...             40   United-States   <=50K
# 3   53            Private  234721  ...             40   United-States   <=50K
# 4   28            Private  338409  ...             40            Cuba   <=50K
#
# [5 rows x 15 columns]

# %%
#Q2
import pandas as pd

df=pd.read_csv("/content/Book1.csv")
df
# Out:
#    Serial No.  gre score  toefl score
# 0           1        337          118
# 1           2        324          107
# 2           3        316          104
# 3           4        322          110
# 4           5        314          103

# %%
(df['toefl score'] > 105) & (df['toefl score'] < 115)
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# Name: toefl score, dtype: bool

# %%
df[df['toefl score'].gt(105) & df['toefl score'].lt(115)]
# Out:
#    Serial No.  gre score  toefl score
# 1           2        324          107
# 3           4        322          110

# %%
df[(df['toefl score'].isin(range(106, 115)))]
# Out:
#    Serial No.  gre score  toefl score
# 1           2        324          107
# 3           4        322          110

# %%
df[(df['toefl score'] > 105) & (df['toefl score'] < 115)]
# Out:
#    Serial No.  gre score  toefl score
# 1           2        324          107
# 3           4        322          110

# %%
#Q7 Q4 retake
#For the given DataFrame df we want to keep only the records with a toefl score greater than 105. 
#Which of the following will not work?
df.where(df['toefl score'] > 105).dropna()
# Out:
#    Serial No.  gre score  toefl score
# 0         1.0      337.0        118.0
# 1         2.0      324.0        107.0
# 3         4.0      322.0        110.0

# %%
df.where(df['toefl score'] > 105)
# Out:
#    Serial No.  gre score  toefl score
# 0         1.0      337.0        118.0
# 1         2.0      324.0        107.0
# 2         NaN        NaN          NaN
# 3         4.0      322.0        110.0
# 4         NaN        NaN          NaN

# %%
df[df['toefl score'] > 105]
# Out:
#    Serial No.  gre score  toefl score
# 0           1        337          118
# 1           2        324          107
# 3           4        322          110

# %%
#Q4
import pandas as pd
s1 = pd.Series({1: 'Alice', 2: 'Jack', 3: 'Molly'})
s2 = pd.Series({'Alice': 1, 'Jack': 2, 'Molly': 3})

# %%
s1.loc[1]
# Out:
# 'Alice'

# %%
#Error
#s2.loc[1]

# %%
s2[1]
# Out:
# 2

# %%
s2.iloc[1]
# Out:
# 2

# %%
#Q1
df=pd.read_csv("/content/Book2.csv",index_col=['(Major)'])
df
# Out:
#               Name  Age Gender
# (Major)
# Mathematics  Alice   20      F
# Sociology     Jack   22      M

# %%
df.T['Mathematics']
# Out:
# Name      Alice
# Age          20
# Gender        F
# Name: Mathematics, dtype: object

# %%
df['Alice']

# %%
df.iloc['Mathematics']

# %%
df['Mathematics']

# %% [markdown]
# #### **RETAKE**

# %%
#Q1
#For the following code, which of the following statements will not return True?

sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj1 = pd.Series(sdata)
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj2 = pd.Series(sdata, index=states)
obj3 = pd.isnull(obj2)

# %%
obj3['California']
# Out:
# True

# %%
import math
math.isnan(obj2['California'])
# Out:
# True

# %%
x=obj2['California']
obj2['California']!=x
# Out:
# True

# %%
obj2['California']==None
# Out:
# False

# %%
#Q2
d = {
    '1': 'Alice',
    '2': 'Bob',
    '3': 'Rita',
    '4': 'Molly',
    '5': 'Ryan'
}
S = pd.Series(d)

# %%
#In the above python code, the keys of the dictionary d represent student ranks and the value for each key is a student name. 
#Which of the following can be used to extract rows with student ranks that are lower than or equal to 3?

S.iloc[0:2]
# Out:
# 1    Alice
# 2      Bob
# dtype: object

# %%
S.iloc[0:3]
# Out:
# 1    Alice
# 2      Bob
# 3     Rita
# dtype: object

# %%
#Q6
df=pd.read_csv("/content/Book3.csv",index_col='Unnamed: 0')
df
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
df=df.drop('Ohio')
df
# Out:
#           one  two  three  four
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15
